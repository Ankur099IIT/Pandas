# %%
import pandas as pd

# %%
# 2 main data type

series = pd.Series(['BMW', 'Toyota', 'Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# Series = one-dimensional # take list

# %%
colours = pd.Series(['Red', 'Blue', 'Yellow'])

# %%
colours
# Out:
# 0       Red
# 1      Blue
# 2    Yellow
# dtype: object

# %%
# Datadrame is 2-dimensional ## take dictionary
car_data = pd.DataFrame({'Car make': series, 'colour': colours})
car_data
# Out:
#   Car make  colour
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda  Yellow

# %%
# Import data # the data shoud be in same folder/directory on which we are working
car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# in pandas axis = o means row
# and axis = 1 means column

# %%
# Export dataframes
exported_car_sales = car_sales.to_csv('exported-car-sales.csv')

# %%
exported_car_sales = pd.read_csv('exported-car-sales.csv') ## unnamed:0 here because we have to export the file without index for that we have to pass an argument in the to_csv("file name", index = False)
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
exported_car_sales = car_sales.to_csv('exported-car-sales.csv', index = False) 
exported_car_sales = pd.read_csv('exported-car-sales.csv') 
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# There is another way to import the data if we dont have that file in our folder. 
# i.e. if we have url of the file for ex: in the github (in raw form)

heart_desease  = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv')

# %%
heart_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## Describe data

# %%
# Attribute

car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns # takes out columns in the file
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe() # to get statistical data in the file. it only works in numeric columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum() # for a single column sum
# Out:
# 40

# %%
len(car_sales) # number of rows in the dataframe
# Out:
# 10

# %% [markdown]
# ## Viewing and Selecting data

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc

animals = pd.Series(['cat', 'dog', 'pandas','snake', 'horse'] )

# %%
animals
# Out:
# 0       cat
# 1       dog
# 2    pandas
# 3     snake
# 4     horse
# dtype: object

# %%
animals.loc[2], car_sales.loc[3] # it gives the index information
# Out:
# ('pandas',
#  Make                    BMW
#  Colour                Black
#  Odometer (KM)         11179
#  Doors                     5
#  Price            $22,000.00
#  Name: 3, dtype: object)

# %%
animals[0:2]
# Out:
# 0    cat
# 1    dog
# dtype: object

# %%
car_sales[0:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
car_sales['Price'] ## or we can do car_sales.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Price'] > '$5000']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Crosstab is for comparing two columns in the data set

pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby

car_sales.groupby(car_sales['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Odometer (KM)'].plot() #plot only takes the numeric data

# %%
Phd_exp = pd.read_csv('Exp data.csv')

# %%
Phd_exp.head()
# Out:
#      Scan Sweep Time (Sec)  Scan Number   Inlet DBT 1   Inlet WBT 1  \
# 0  2021-08-12 16:53:05.315          1.0        32.145        27.210
# 1  2021-08-12 16:53:10.291          2.0        32.149        27.202
# 2  2021-08-12 16:53:15.268          3.0        32.157        27.195
# 3  2021-08-12 16:53:20.285          4.0        32.157        27.189
# 4  2021-08-12 16:53:25.282          5.0        32.176        27.179
#
#     Inlet DBT 2   Inlet WBT 2   Inlet DBT 3   Inlet WBT 3   Inlet DBT 4  \
# 0        33.268        26.651        32.284        27.102        32.112
# 1        33.290        26.638        32.299        27.090        32.114
# 2        33.319        26.622        32.319        27.078        32.114
# 3        33.334        26.611        32.327        27.066        32.116
# 4        33.364        26.597        32.360        27.068        32.126
#
#     Inlet WBT 4  ...     HWT  Pressure drop (Adc)  Unnamed: 22   Avg DBT  \
# ...

# %%
Phd_exp['Avg DBT'].plot()

# %%
Phd_exp.tail()
# Out:
#        Scan Sweep Time (Sec)  Scan Number   Inlet DBT 1   Inlet WBT 1  \
# 128  2021-08-12 17:03:45.278        129.0        29.948        28.106
# 129  2021-08-12 17:03:50.271        130.0        29.906        28.131
# 130  2021-08-12 17:03:55.284        131.0        29.890        28.134
# 131  2021-08-12 17:04:00.276        132.0        29.871        28.135
# 132                      NaN          NaN           NaN           NaN
#
#       Inlet DBT 2   Inlet WBT 2   Inlet DBT 3   Inlet WBT 3   Inlet DBT 4  \
# 128        33.043        27.103        31.741        27.564        30.584
# 129        33.040        27.151        31.702        27.603        30.620
# 130        33.058        27.155        31.696        27.612        30.641
# 131        33.083        27.147        31.716        27.610        30.660
# 132           NaN           NaN           NaN           NaN           NaN
#
#       Inlet WBT 4  ...        HWT  Pressure drop (Adc)  Unnamed: 22  \
# ...

# %%
Phd_exp.describe()
# Out:
#        Scan Number   Inlet DBT 1   Inlet WBT 1   Inlet DBT 2   Inlet WBT 2  \
# count   132.000000    132.000000    132.000000    132.000000    132.000000
# mean     66.500000     30.903273     27.487227     32.710712     26.771962
# std      38.249183      1.029525      0.384602      0.517495      0.287537
# min       1.000000     29.577000     27.001000     32.031000     26.389000
# 25%      33.750000     29.947750     27.141750     32.158000     26.505250
# 50%      66.500000     30.677000     27.401000     32.825500     26.697000
# 75%      99.250000     32.146000     27.946750     33.231250     27.029500
# max     132.000000     32.425000     28.135000     33.586000     27.266000
#
#         Inlet DBT 3   Inlet WBT 3   Inlet DBT 4   Inlet WBT 4       CWT 1  \
# count    132.000000    132.000000    132.000000    132.000000  132.000000
# mean      31.800614     27.307462     30.868083     27.594364   39.167659
# ...

# %%
Phd_exp['Avg DBT'].hist()

# %%
Phd_exp.dtypes
# Out:
# Scan Sweep Time (Sec)          object
# Scan Number                   float64
#  Inlet DBT 1                  float64
#  Inlet WBT 1                  float64
#  Inlet DBT 2                  float64
#  Inlet WBT 2                  float64
#  Inlet DBT 3                  float64
#  Inlet WBT 3                  float64
#  Inlet DBT 4                  float64
#  Inlet WBT 4                  float64
#  CWT 1                        float64
#  CWT 2                        float64
#  CWT 3                        float64
#  CWT 4                        float64
#  CWT (Return pipe)            float64
#  Outlet DBT 1                 float64
#  Outlet WBT 1                 float64
#  Outlet DBT 2                 float64
#  Outlet WBT 2                 float64
#  Tank temp                    float64
#  HWT                          float64
# Pressure drop (Adc)           float64
# Unnamed: 22                   float64
# Avg DBT                       float64
# Avg WBT                       float64
# ...

# %%
len(Phd_exp) # number of rows
# Out:
# 133

# %%
# convert our Price column in the dataframe from object to float/int

car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]', '').astype(float)

# %%
car_sales['Price']
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %% [markdown]
# ## Manipulating Data

# %%
# if we really want to change something in the Dataframe using method/funct then we 
# have to reassign them in the column

car_sales['Make'] =  car_sales['Make'].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   4000.0
# 1   HONDA    Red          87899      4   5000.0
# 2  TOYOTA   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  NISSAN  White         213095      4   3500.0
# 5  TOYOTA  Green          99213      4   4500.0
# 6   HONDA   Blue          45698      4   7500.0
# 7   HONDA   Blue          54738      4   7000.0
# 8  TOYOTA  White          60000      4   6250.0
# 9  NISSAN  White          31600      4   9700.0

# %%
Phd_exp
# Out:
#        Scan Sweep Time (Sec)  Scan Number   Inlet DBT 1   Inlet WBT 1  \
# 0    2021-08-12 16:53:05.315          1.0        32.145        27.210
# 1    2021-08-12 16:53:10.291          2.0        32.149        27.202
# 2    2021-08-12 16:53:15.268          3.0        32.157        27.195
# 3    2021-08-12 16:53:20.285          4.0        32.157        27.189
# 4    2021-08-12 16:53:25.282          5.0        32.176        27.179
# ..                       ...          ...           ...           ...
# 128  2021-08-12 17:03:45.278        129.0        29.948        28.106
# 129  2021-08-12 17:03:50.271        130.0        29.906        28.131
# 130  2021-08-12 17:03:55.284        131.0        29.890        28.134
# 131  2021-08-12 17:04:00.276        132.0        29.871        28.135
# 132                      NaN          NaN           NaN           NaN
#
#       Inlet DBT 2   Inlet WBT 2   Inlet DBT 3   Inlet WBT 3   Inlet DBT 4  \
# ...

# %%
# it converts the NaN value to some define value (here it is mean)

Phd_exp['average outlet DBT'].fillna(Phd_exp['average outlet DBT'].mean())
# Out:
# 0      40.948217
# 1      40.948217
# 2      40.948217
# 3      40.948217
# 4      40.948217
#          ...
# 128    41.275000
# 129    39.571500
# 130    36.706500
# 131    34.895500
# 132    40.948217
# Name: average outlet DBT, Length: 133, dtype: float64

# %%
Phd_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Scan Sweep Time (Sec)       132 non-null    object
#  1   Scan Number                 132 non-null    float64
#  2    Inlet DBT 1                132 non-null    float64
#  3    Inlet WBT 1                132 non-null    float64
#  4    Inlet DBT 2                132 non-null    float64
#  5    Inlet WBT 2                132 non-null    float64
#  6    Inlet DBT 3                132 non-null    float64
#  7    Inlet WBT 3                132 non-null    float64
#  8    Inlet DBT 4                132 non-null    float64
#  9    Inlet WBT 4                132 non-null    float64
#  10   CWT 1                      132 non-null    float64
#  11   CWT 2                      132 non-null    float64
#  12   CWT 3                      132 non-null    float64
# ...

# %%
Phd_exp['Avg WBT']
# Out:
# 0      26.878750
# 1      26.868500
# 2      26.857000
# 3      26.847250
# 4      26.838500
#          ...
# 128    27.648000
# 129    27.686750
# 130    27.698000
# 131    27.702250
# 132    27.664914
# Name: Avg WBT, Length: 133, dtype: float64

# %%
Phd_exp.dropna() # it will remove all the rows having NaN data in them
# Out:
# Empty DataFrame
# Columns: [Scan Sweep Time (Sec), Scan Number,  Inlet DBT 1,  Inlet WBT 1,  Inlet DBT 2,  Inlet WBT 2,  Inlet DBT 3,  Inlet WBT 3,  Inlet DBT 4,  Inlet WBT 4,  CWT 1,  CWT 2,  CWT 3,  CWT 4,  CWT (Return pipe),  Outlet DBT 1,  Outlet WBT 1,  Outlet DBT 2,  Outlet WBT 2,  Tank temp,  HWT, Pressure drop (Adc), Unnamed: 22, Avg DBT, Avg WBT, Avg CWT (Collection basin), Range, Approach, average outlet DBT, average outlet WBT]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Column from series

seats_column = pd.Series([5,5,5,5,5])
car_sales['Seats'] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  TOYOTA  White         150043      4   4000.0    5.0
# 1   HONDA    Red          87899      4   5000.0    5.0
# 2  TOYOTA   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  NISSAN  White         213095      4   3500.0    5.0
# 5  TOYOTA  Green          99213      4   4500.0    NaN
# 6   HONDA   Blue          45698      4   7500.0    NaN
# 7   HONDA   Blue          54738      4   7000.0    NaN
# 8  TOYOTA  White          60000      4   6250.0    NaN
# 9  NISSAN  White          31600      4   9700.0    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  TOYOTA  White         150043      4   4000.0    5.0
# 1   HONDA    Red          87899      4   5000.0    5.0
# 2  TOYOTA   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  NISSAN  White         213095      4   3500.0    5.0
# 5  TOYOTA  Green          99213      4   4500.0    5.0
# 6   HONDA   Blue          45698      4   7500.0    5.0
# 7   HONDA   Blue          54738      4   7000.0    5.0
# 8  TOYOTA  White          60000      4   6250.0    5.0
# 9  NISSAN  White          31600      4   9700.0    5.0

# %%
# Add column from python list

fuel_economy = [2,3,4,5,5,6,7,7,7,9] # list should be of same length as the data frame
car_sales['Fuel_economy'] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_economy
# 0  TOYOTA  White         150043      4   4000.0    5.0             2
# 1   HONDA    Red          87899      4   5000.0    5.0             3
# 2  TOYOTA   Blue          32549      3   7000.0    5.0             4
# 3     BMW  Black          11179      5  22000.0    5.0             5
# 4  NISSAN  White         213095      4   3500.0    5.0             5
# 5  TOYOTA  Green          99213      4   4500.0    5.0             6
# 6   HONDA   Blue          45698      4   7500.0    5.0             7
# 7   HONDA   Blue          54738      4   7000.0    5.0             7
# 8  TOYOTA  White          60000      4   6250.0    5.0             7
# 9  NISSAN  White          31600      4   9700.0    5.0             9

# %%
# Create a column from the existing columns in the dataframe

car_sales['Fuel used (lt)'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel_economy']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_economy  \
# 0  TOYOTA  White         150043      4   4000.0    5.0             2
# 1   HONDA    Red          87899      4   5000.0    5.0             3
# 2  TOYOTA   Blue          32549      3   7000.0    5.0             4
# 3     BMW  Black          11179      5  22000.0    5.0             5
# 4  NISSAN  White         213095      4   3500.0    5.0             5
# 5  TOYOTA  Green          99213      4   4500.0    5.0             6
# 6   HONDA   Blue          45698      4   7500.0    5.0             7
# 7   HONDA   Blue          54738      4   7000.0    5.0             7
# 8  TOYOTA  White          60000      4   6250.0    5.0             7
# 9  NISSAN  White          31600      4   9700.0    5.0             9
#
#    Fuel used (lt)
# 0         3000.86
# 1         2636.97
# 2         1301.96
# 3          558.95
# 4        10654.75
# 5         5952.78
# 6         3198.86
# 7         3831.66
# 8         4200.00
# ...

# %%
# Column from a single value

car_sales['No. of wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_economy  \
# 0  TOYOTA  White         150043      4   4000.0    5.0             2
# 1   HONDA    Red          87899      4   5000.0    5.0             3
# 2  TOYOTA   Blue          32549      3   7000.0    5.0             4
# 3     BMW  Black          11179      5  22000.0    5.0             5
# 4  NISSAN  White         213095      4   3500.0    5.0             5
# 5  TOYOTA  Green          99213      4   4500.0    5.0             6
# 6   HONDA   Blue          45698      4   7500.0    5.0             7
# 7   HONDA   Blue          54738      4   7000.0    5.0             7
# 8  TOYOTA  White          60000      4   6250.0    5.0             7
# 9  NISSAN  White          31600      4   9700.0    5.0             9
#
#    Fuel used (lt)  No. of wheels
# 0         3000.86              4
# 1         2636.97              4
# 2         1301.96              4
# 3          558.95              4
# 4        10654.75              4
# ...

# %%
# Dropping a column. Reasign it to car_sales is require if we want change the actual list
car_sales.drop('Doors',axis=1)
# Out:
#      Make Colour  Odometer (KM)    Price  Seats  Fuel_economy  Fuel used (lt)  \
# 0  TOYOTA  White         150043   4000.0    5.0             2         3000.86
# 1   HONDA    Red          87899   5000.0    5.0             3         2636.97
# 2  TOYOTA   Blue          32549   7000.0    5.0             4         1301.96
# 3     BMW  Black          11179  22000.0    5.0             5          558.95
# 4  NISSAN  White         213095   3500.0    5.0             5        10654.75
# 5  TOYOTA  Green          99213   4500.0    5.0             6         5952.78
# 6   HONDA   Blue          45698   7500.0    5.0             7         3198.86
# 7   HONDA   Blue          54738   7000.0    5.0             7         3831.66
# 8  TOYOTA  White          60000   6250.0    5.0             7         4200.00
# 9  NISSAN  White          31600   9700.0    5.0             9         2844.00
#
#    No. of wheels
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# ...

# %%
# To Shuffle our Dataframe

car_sales_shuffle = car_sales.sample(frac = 1) # frac is in the fraction of the total data we want to shuffle
# here we want to shuffle 100% so 1

# %%
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_economy  \
# 2  TOYOTA   Blue          32549      3   7000.0    5.0             4
# 1   HONDA    Red          87899      4   5000.0    5.0             3
# 8  TOYOTA  White          60000      4   6250.0    5.0             7
# 5  TOYOTA  Green          99213      4   4500.0    5.0             6
# 7   HONDA   Blue          54738      4   7000.0    5.0             7
# 6   HONDA   Blue          45698      4   7500.0    5.0             7
# 9  NISSAN  White          31600      4   9700.0    5.0             9
# 4  NISSAN  White         213095      4   3500.0    5.0             5
# 0  TOYOTA  White         150043      4   4000.0    5.0             2
# 3     BMW  Black          11179      5  22000.0    5.0             5
#
#    Fuel used (lt)  No. of wheels
# 2         1301.96              4
# 1         2636.97              4
# 8         4200.00              4
# 5         5952.78              4
# 7         3831.66              4
# ...
